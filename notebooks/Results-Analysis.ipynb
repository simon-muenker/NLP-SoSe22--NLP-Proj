# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 6]

EXP_PATH: str = '../experiments'

# %%
data: dict = {
    'transformer': pd.read_csv(f'{EXP_PATH}/train.1.000/transformer/train.csv'),
    'hybrid': pd.read_csv(f'{EXP_PATH}/train.1.000/hybrid/train.csv'),
}

# %%
results: pd.DataFrame = pd.DataFrame()
labels: list = []

for label, df in data.items():
    results[f'{label}(train)'] = df['f1_train']
    results[f'{label}(eval)'] = df['f1_eval']
    labels.extend([f'{label}(train)', f'{label}(eval)'])

results.plot(
    y=labels,
    grid=True,
    xlabel='Epoch',
    ylabel='F1-Score',
    style=['--', '-', '--', '-'])
# Out:
# <AxesSubplot:xlabel='Epoch', ylabel='F1-Score'>
